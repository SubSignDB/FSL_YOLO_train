# %% [markdown]
# <a href="https://colab.research.google.com/github/SubSignDB/FSL_YOLO_train/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi
# Out:
# Wed Aug  5 11:39:04 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data

# %%
# !pip install albumentations opencv-python matplotlib

import cv2
import os
import shutil
import random
import albumentations as A
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# =========================================================
# Configuration
# =========================================================

SEED = 42
TRAIN_RATIO = 0.90
AUGMENTATIONS_PER_IMAGE = 3

# These folders should contain only the 452 original images
# and their corresponding YOLO label files.
input_images = "/content/custom_data/images"
input_labels = "/content/custom_data/labels"

# Use a new folder instead of writing into the source folder.
output_root = "/content/split_data"

train_images = os.path.join(output_root, "images", "train")
val_images = os.path.join(output_root, "images", "val")
train_labels = os.path.join(output_root, "labels", "train")
val_labels = os.path.join(output_root, "labels", "val")

for folder in [
    train_images,
    val_images,
    train_labels,
    val_labels
]:
    os.makedirs(folder, exist_ok=True)

random.seed(SEED)

# =========================================================
# Augmentation pipeline
# =========================================================

transform = A.Compose(
    [
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.ColorJitter(
            brightness=0.2,
            contrast=0.2,
            saturation=0.2,
            hue=0.1,
            p=0.5
        )
    ],
    bbox_params=A.BboxParams(
        format="yolo",
        label_fields=["class_labels"]
    )
)

# =========================================================
# Helper functions
# =========================================================

def load_yolo_labels(label_path):
    """Load bounding boxes and classes from a YOLO label file."""

    boxes = []
    classes = []

    # Missing labels are treated as an image with no signer.
    if not os.path.exists(label_path):
        return boxes, classes

    with open(label_path, "r") as file:
        for line in file:
            parts = line.strip().split()

            if len(parts) != 5:
                print(
                    f"Warning: Skipping malformed label in "
                    f"{label_path}: {line.strip()}"
                )
                continue

            cls, x, y, w, h = map(float, parts)

            boxes.append([x, y, w, h])
            classes.append(int(cls))

    return boxes, classes


def save_yolo_labels(label_path, boxes, classes):
    """Save bounding boxes and classes in YOLO format."""

    with open(label_path, "w") as file:
        for cls, (x, y, w, h) in zip(classes, boxes):
            file.write(
                f"{cls} {x:.6f} {y:.6f} "
                f"{w:.6f} {h:.6f}\n"
            )


def copy_original_pair(
    img_name,
    destination_images,
    destination_labels
):
    """Copy one original image and its corresponding label."""

    image_source = os.path.join(input_images, img_name)
    image_destination = os.path.join(
        destination_images,
        img_name
    )

    base_name = os.path.splitext(img_name)[0]
    label_source = os.path.join(
        input_labels,
        base_name + ".txt"
    )
    label_destination = os.path.join(
        destination_labels,
        base_name + ".txt"
    )

    shutil.copy2(image_source, image_destination)

    if os.path.exists(label_source):
        shutil.copy2(label_source, label_destination)
    else:
        # Create an empty label for a negative/no-signer image.
        open(label_destination, "w").close()


def show_image_with_boxes(image, boxes, classes):
    """Display an image with its YOLO bounding boxes."""

    figure, axis = plt.subplots(1, figsize=(6, 6))
    axis.imshow(image)

    height, width, _ = image.shape

    for (x, y, box_width, box_height), cls in zip(
        boxes,
        classes
    ):
        x1 = (x - box_width / 2) * width
        y1 = (y - box_height / 2) * height

        rectangle = patches.Rectangle(
            (x1, y1),
            box_width * width,
            box_height * height,
            linewidth=2,
            edgecolor="red",
            facecolor="none"
        )

        axis.add_patch(rectangle)

        axis.text(
            x1,
            y1 - 5,
            f"Class {cls}",
            color="yellow",
            fontsize=8,
            bbox=dict(
                facecolor="black",
                alpha=0.5
            )
        )

    plt.axis("off")
    plt.show()


# =========================================================
# Step 1: Find original images
# =========================================================

valid_extensions = (
    ".jpg",
    ".jpeg",
    ".png",
    ".bmp",
    ".webp"
)

original_images = [
    filename
    for filename in os.listdir(input_images)
    if filename.lower().endswith(valid_extensions)
    and "_aug" not in filename.lower()
]

original_images.sort()
random.shuffle(original_images)

print(f"Original images found: {len(original_images)}")

# =========================================================
# Step 2: Split originals before augmentation
# =========================================================

split_index = int(len(original_images) * TRAIN_RATIO)

training_originals = original_images[:split_index]
validation_originals = original_images[split_index:]

print(f"Training originals: {len(training_originals)}")
print(f"Validation originals: {len(validation_originals)}")

# =========================================================
# Step 3: Copy the original images into their partitions
# =========================================================

for img_name in training_originals:
    copy_original_pair(
        img_name,
        train_images,
        train_labels
    )

for img_name in validation_originals:
    copy_original_pair(
        img_name,
        val_images,
        val_labels
    )

# =========================================================
# Step 4: Augment only the training originals
# =========================================================

generated_image_paths = []

for img_name in training_originals:
    img_path = os.path.join(input_images, img_name)

    base_name = os.path.splitext(img_name)[0]
    label_path = os.path.join(
        input_labels,
        base_name + ".txt"
    )

    image = cv2.imread(img_path)

    if image is None:
        print(
            f"Warning: Could not read {img_name}. Skipping."
        )
        continue

    image = cv2.cvtColor(
        image,
        cv2.COLOR_BGR2RGB
    )

    boxes, classes = load_yolo_labels(label_path)

    for augmentation_number in range(
        AUGMENTATIONS_PER_IMAGE
    ):
        try:
            augmented = transform(
                image=image,
                bboxes=boxes,
                class_labels=classes
            )

            augmented_image = augmented["image"]
            augmented_boxes = augmented["bboxes"]
            augmented_classes = augmented["class_labels"]

        except ValueError as error:
            print(
                f"Warning: Could not augment "
                f"{img_name}, version "
                f"{augmentation_number}: {error}"
            )
            continue

        augmented_name = (
            f"{base_name}_aug"
            f"{augmentation_number}.jpg"
        )

        augmented_image_path = os.path.join(
            train_images,
            augmented_name
        )

        augmented_label_path = os.path.join(
            train_labels,
            f"{base_name}_aug"
            f"{augmentation_number}.txt"
        )

        cv2.imwrite(
            augmented_image_path,
            cv2.cvtColor(
                augmented_image,
                cv2.COLOR_RGB2BGR
            )
        )

        save_yolo_labels(
            augmented_label_path,
            augmented_boxes,
            augmented_classes
        )

        generated_image_paths.append(
            augmented_image_path
        )

# =========================================================
# Step 5: Calculate and report dataset statistics
# =========================================================

def count_images(folder):
    """Count image files in a folder."""
    return len([
        filename
        for filename in os.listdir(folder)
        if filename.lower().endswith(valid_extensions)
    ])


def count_augmented_images(folder):
    """Count generated augmented images."""
    return len([
        filename
        for filename in os.listdir(folder)
        if filename.lower().endswith(valid_extensions)
        and "_aug" in filename.lower()
    ])


def count_unaugmented_images(folder):
    """Count original, unaugmented images."""
    return len([
        filename
        for filename in os.listdir(folder)
        if filename.lower().endswith(valid_extensions)
        and "_aug" not in filename.lower()
    ])


# Count original images with and without signer annotations.
original_with_signer = 0
original_without_signer = 0
original_missing_label = 0
original_box_count = 0

for img_name in original_images:
    base_name = os.path.splitext(img_name)[0]

    label_path = os.path.join(
        input_labels,
        base_name + ".txt"
    )

    if not os.path.exists(label_path):
        original_missing_label += 1
        continue

    boxes, classes = load_yolo_labels(label_path)

    if len(boxes) > 0:
        original_with_signer += 1
        original_box_count += len(boxes)
    else:
        original_without_signer += 1


# Training statistics
training_unaugmented = count_unaugmented_images(
    train_images
)

training_augmented = count_augmented_images(
    train_images
)

final_training_count = count_images(
    train_images
)


# Validation statistics
validation_unaugmented = count_unaugmented_images(
    val_images
)

validation_augmented = count_augmented_images(
    val_images
)

final_validation_count = count_images(
    val_images
)


# Complete dataset total
final_dataset_count = (
    final_training_count
    + final_validation_count
)


print("\n" + "=" * 50)
print("ORIGINAL DATASET")
print("=" * 50)

print(
    f"Total original images: "
    f"{len(original_images)}"
)

print(
    f"Original images with signer annotations: "
    f"{original_with_signer}"
)

print(
    f"Original images without signer annotations: "
    f"{original_without_signer}"
)

print(
    f"Original images with missing label files: "
    f"{original_missing_label}"
)

print(
    f"Total signer bounding boxes: "
    f"{original_box_count}"
)


print("\n" + "=" * 50)
print("TRAINING SET")
print("=" * 50)

print(
    f"Unaugmented training images: "
    f"{training_unaugmented}"
)

print(
    f"Augmented training images: "
    f"{training_augmented}"
)

print(
    f"Total training images: "
    f"{final_training_count}"
)


print("\n" + "=" * 50)
print("VALIDATION SET")
print("=" * 50)

print(
    f"Unaugmented validation images: "
    f"{validation_unaugmented}"
)

print(
    f"Augmented validation images: "
    f"{validation_augmented}"
)

print(
    f"Total validation images: "
    f"{final_validation_count}"
)


print("\n" + "=" * 50)
print("FINAL DATASET")
print("=" * 50)

print(
    f"Total unaugmented images: "
    f"{training_unaugmented + validation_unaugmented}"
)

print(
    f"Total augmented images: "
    f"{training_augmented + validation_augmented}"
)

print(
    f"Total images after augmentation: "
    f"{final_dataset_count}"
)

print(
    f"Training percentage: "
    f"{final_training_count / final_dataset_count * 100:.2f}%"
)

print(
    f"Validation percentage: "
    f"{final_validation_count / final_dataset_count * 100:.2f}%"
)

# =========================================================
# Step 6: Preview augmented training images
# =========================================================

if generated_image_paths:
    preview_count = min(
        10,
        len(generated_image_paths)
    )

    preview_paths = random.sample(
        generated_image_paths,
        preview_count
    )

    print(
        f"\nShowing {preview_count} augmented "
        f"training samples..."
    )

    for image_path in preview_paths:
        image_name = os.path.basename(image_path)
        base_name = os.path.splitext(image_name)[0]

        label_path = os.path.join(
            train_labels,
            base_name + ".txt"
        )

        image = cv2.imread(image_path)

        if image is None:
            continue

        image = cv2.cvtColor(
            image,
            cv2.COLOR_BGR2RGB
        )

        boxes, classes = load_yolo_labels(
            label_path
        )

        show_image_with_boxes(
            image,
            boxes,
            classes
        )
else:
    print("No augmented images were generated.")
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (5.0.0.93)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.13.4)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (5.0.0.93)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Original images found: 452
# Training originals: 406
# Validation originals: 46
#
# ==================================================
# ORIGINAL DATASET
# ==================================================
# Total original images: 452
# Original images with signer annotations: 426
# Original images without signer annotations: 26
# Original images with missing label files: 0
# Total signer bounding boxes: 426
#
# ==================================================
# TRAINING SET
# ==================================================
# Unaugmented training images: 406
# Augmented training images: 1218
# Total training images: 1624
#
# ==================================================
# VALIDATION SET
# ==================================================
# Unaugmented validation images: 46
# Augmented validation images: 0
# Total validation images: 46
#
# ==================================================
# FINAL DATASET
# ==================================================
# Total unaugmented images: 452
# Total augmented images: 1218
# Total images after augmentation: 1670
# Training percentage: 97.25%
# Validation percentage: 2.75%
#
# Showing 10 augmented training samples...

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.115-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.29.7)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.115-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.115 ultralytics-thop-2.1.6

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
import yaml
import os


def create_data_yaml(
    path_to_classes_txt,
    path_to_data_yaml
):
    # Check whether classes.txt exists
    if not os.path.exists(path_to_classes_txt):
        print(
            "classes.txt was not found at "
            f"{path_to_classes_txt}"
        )
        return

    # Read class names
    with open(path_to_classes_txt, "r") as file:
        classes = [
            line.strip()
            for line in file
            if line.strip()
        ]

    if not classes:
        print("classes.txt does not contain any classes.")
        return

    # Match the corrected dataset folder structure
    data = {
        "path": "/content/split_data",
        "train": "images/train",
        "val": "images/val",
        "nc": len(classes),
        "names": classes
    }

    # Write the YAML configuration
    with open(path_to_data_yaml, "w") as file:
        yaml.dump(
            data,
            file,
            sort_keys=False
        )

    print(
        f"Created configuration file at "
        f"{path_to_data_yaml}"
    )


# Input and output paths
path_to_classes_txt = (
    "/content/custom_data/classes.txt"
)

path_to_data_yaml = (
    "/content/split_data/data.yaml"
)

create_data_yaml(
    path_to_classes_txt,
    path_to_data_yaml
)

print("\nFile contents:\n")

with open(path_to_data_yaml, "r") as file:
    print(file.read())
# Out:
# Created configuration file at /content/split_data/data.yaml
#
# File contents:
#
# path: /content/split_data
# train: images/train
# val: images/val
# nc: 1
# names:
# - Interpreter

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
import os

folders = {
    "Training images":
        "/content/split_data/images/train",

    "Training labels":
        "/content/split_data/labels/train",

    "Validation images":
        "/content/split_data/images/val",

    "Validation labels":
        "/content/split_data/labels/val"
}

for label, folder in folders.items():
    if os.path.exists(folder):
        print(
            f"{label}: "
            f"{len(os.listdir(folder))}"
        )
    else:
        print(
            f"{label}: folder not found"
        )
# Out:
# Training images: 1624
# Training labels: 1624
# Validation images: 46
# Validation labels: 46

# %%
# models to compare

models = [
    "yolo11n.pt",
    "yolo11s.pt",
    "yolo11m.pt",
    "yolo11l.pt"
]

# %%
# Corrected dataset configuration
data_path = "/content/split_data/data.yaml"

# Use a new folder for the corrected experiments
project_root = "/content/runs_compare_corrected"

epochs = 40
imgsz = 640
seed = 42

for model_path in models:
    run_name = model_path.replace(".pt", "")

    print(
        f"\n===== Training {run_name} =====\n"
    )

    # !yolo detect train \
        data={data_path} \
        model={model_path} \
        epochs={epochs} \
        imgsz={imgsz} \
        seed={seed} \
        deterministic=True \
        project={project_root} \
        name={run_name}
# Out:
# ===== Training yolo11n =====
#
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 262.9MB/s 0.0s
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/split_data/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs_compare_corrected, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs_compare_corrected/yolo11n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 83.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 201.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3168.0±1012.6 MB/s, size: 250.3 KB)
# train: Scanning /content/split_data/labels/train... 1624 images, 96 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1624/1624 2.4Kit/s 0.7s
# train: New cache created: /content/split_data/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1320.4±854.3 MB/s, size: 76.0 KB)
# val: Scanning /content/split_data/labels/val... 46 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 1.4Kit/s 0.0s
# val: New cache created: /content/split_data/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/runs_compare_corrected/yolo11n/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs_compare_corrected/yolo11n
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      2.19G     0.5027      1.511      0.863         11        640: 100% ━━━━━━━━━━━━ 102/102 1.8it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3s/it 6.7s
#                    all         46         44      0.998          1      0.995      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      2.32G     0.3841      0.736     0.8094         11        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.999          1      0.995      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      2.32G     0.3487     0.5126     0.8102         12        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.997          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      2.32G     0.3221     0.3884     0.8087         15        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      2.32G     0.3025     0.3168     0.8025         12        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         46         44      0.997          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      2.32G     0.2981      0.295     0.7996         13        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      2.32G     0.2909     0.2863     0.8015         13        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.994          1      0.995      0.977
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      2.32G     0.2796     0.2629     0.8004         18        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.977          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      2.32G     0.2826      0.254     0.7971         16        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 33.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         46         44      0.996          1      0.995      0.985
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      2.32G     0.2596     0.2344     0.7981         14        640: 100% ━━━━━━━━━━━━ 102/102 3.2it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      2.32G     0.2663     0.2298     0.7955         16        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 34.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.976          1      0.994      0.979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      2.32G     0.2504     0.2154     0.7962         10        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         46         44      0.976          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      2.32G     0.2504     0.2179     0.8012         18        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      2.32G     0.2475     0.2097     0.7933          9        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         46         44      0.992          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      2.32G      0.242     0.2068     0.7909          6        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.1it/s 0.4s
#                    all         46         44      0.993          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      2.32G     0.2385     0.1991     0.7968         12        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      2.32G     0.2294     0.1896     0.7923         14        640: 100% ━━━━━━━━━━━━ 102/102 3.2it/s 32.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s
#                    all         46         44      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      2.32G     0.2316     0.1958     0.7916         16        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      2.32G     0.2263     0.1824      0.787          8        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         46         44      0.982          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      2.32G     0.2237     0.1861     0.7934         18        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.991          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      2.32G     0.2194     0.1817     0.7881         18        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      2.32G     0.2224     0.1808     0.7901         18        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         46         44      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      2.32G     0.2171     0.1761     0.7877         15        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      2.32G     0.2155     0.1739     0.7916         16        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.987          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      2.32G     0.2121     0.1678      0.792         11        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      2.32G      0.213      0.163     0.7894          8        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.7it/s 0.3s
#                    all         46         44      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      2.32G     0.2035     0.1583     0.7877         11        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      2.32G     0.2024     0.1579     0.7932         22        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.991          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      2.32G     0.2003     0.1538     0.7906         16        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      2.32G     0.1961     0.1516     0.7871         17        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s
#                    all         46         44      0.978          1      0.995      0.995
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      2.32G     0.1946     0.1489     0.7969          8        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      2.32G     0.1946      0.139     0.7908          7        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      2.32G     0.1924     0.1433     0.7935          8        640: 100% ━━━━━━━━━━━━ 102/102 3.3it/s 31.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s
#                    all         46         44      0.977          1      0.992      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      2.32G     0.1867      0.139     0.7926          6        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.986          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      2.32G     0.1814     0.1348     0.7903          8        640: 100% ━━━━━━━━━━━━ 102/102 3.2it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      2.32G     0.1778     0.1284     0.7916          8        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.996          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      2.32G     0.1711     0.1221     0.7865          8        640: 100% ━━━━━━━━━━━━ 102/102 3.2it/s 32.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44       0.99          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      2.32G     0.1686     0.1195     0.7997          8        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.7it/s 0.4s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      2.32G     0.1661     0.1159     0.7921          7        640: 100% ━━━━━━━━━━━━ 102/102 3.2it/s 32.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      2.32G      0.166     0.1113     0.7951          5        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.8s
#                    all         46         44      0.978          1      0.995      0.995
#
# 40 epochs completed in 0.396 hours.
# Optimizer stripped from /content/runs_compare_corrected/yolo11n/weights/last.pt, 5.4MB
# Optimizer stripped from /content/runs_compare_corrected/yolo11n/weights/best.pt, 5.4MB
#
# Validating /content/runs_compare_corrected/yolo11n/weights/best.pt...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.978          1      0.995      0.992
# Speed: 0.2ms preprocess, 2.9ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /content/runs_compare_corrected/yolo11n
# 💡 Learn more at https://docs.ultralytics.com/modes/train
#
# ===== Training yolo11s =====
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 354.4MB/s 0.1s
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/split_data/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs_compare_corrected, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs_compare_corrected/yolo11s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,179 parameters, 9,428,163 gradients, 21.7 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3031.6±553.0 MB/s, size: 250.3 KB)
# train: Scanning /content/split_data/labels/train.cache... 1624 images, 96 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1624/1624 194.6Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1370.0±959.6 MB/s, size: 76.0 KB)
# val: Scanning /content/split_data/labels/val.cache... 46 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 2.8Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/runs_compare_corrected/yolo11s/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs_compare_corrected/yolo11s
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      4.07G     0.4328     0.8818     0.8487         11        640: 100% ━━━━━━━━━━━━ 102/102 1.7it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7s/it 7.4s
#                    all         46         44      0.766      0.932      0.837      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      4.34G     0.3794     0.3807     0.8187         11        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         46         44      0.268      0.727      0.244      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      4.34G     0.3581     0.3374     0.8154         12        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.904          1      0.978      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      4.34G     0.3384     0.3028     0.8138         15        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.995          1      0.995      0.979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      4.34G     0.3083     0.2756     0.8052         12        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.982          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      4.34G     0.2929     0.2638     0.8018         13        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         46         44      0.987          1      0.995      0.982
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      4.34G     0.3017      0.272     0.8042         13        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 34.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.995          1      0.995      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      4.34G     0.2816     0.2454     0.8024         18        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s
#                    all         46         44      0.987          1      0.995      0.978
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      4.34G     0.2865     0.2431     0.7978         16        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.975          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      4.34G     0.2715     0.2288     0.8016         14        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.999          1      0.995      0.981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      4.34G     0.2651     0.2342     0.7962         16        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 33.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         46         44      0.976          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      4.34G     0.2559      0.217     0.7979         10        640: 100% ━━━━━━━━━━━━ 102/102 2.7it/s 37.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      4.34G     0.2461     0.2044     0.7994         18        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      4.34G     0.2407     0.2002     0.7917          9        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s
#                    all         46         44      0.997          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      4.34G     0.2444     0.2004     0.7897          6        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         46         44      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      4.34G     0.2354     0.1954     0.7962         12        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      4.34G     0.2295     0.1903      0.793         14        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.995          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      4.34G     0.2386     0.1946     0.7924         16        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      4.34G     0.2303     0.1838     0.7872          8        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         46         44      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      4.34G     0.2215       0.18     0.7928         18        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 34.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         46         44      0.986          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      4.34G     0.2192     0.1803     0.7884         18        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         46         44      0.977          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      4.34G     0.2192     0.1808     0.7899         18        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         46         44      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      4.34G     0.2108     0.1696     0.7867         15        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         46         44      0.995          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      4.34G     0.2115     0.1682     0.7918         16        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         46         44      0.997          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      4.34G     0.2075     0.1629     0.7913         11        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s
#                    all         46         44      0.975          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      4.34G     0.2104     0.1639     0.7898          8        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 34.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.978          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      4.34G     0.2021     0.1559     0.7868         11        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.995          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      4.34G      0.197     0.1525     0.7918         22        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s
#                    all         46         44      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      4.34G     0.1917     0.1487     0.7895         16        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         46         44      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      4.34G     0.1911     0.1491     0.7865         17        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         46         44       0.98          1      0.995      0.992
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      4.34G     0.1912     0.1436     0.7958          8        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         46         44      0.977          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      4.34G      0.189     0.1364     0.7902          7        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         46         44      0.977          1      0.976      0.976
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      4.34G     0.1895     0.1365     0.7939          8        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         46         44      0.977          1      0.985      0.985
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      4.34G     0.1825     0.1328      0.794          6        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s
#                    all         46         44      0.977          1      0.979      0.979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      4.34G     0.1789     0.1313     0.7898          8        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.977          1      0.983      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      4.34G     0.1769     0.1266     0.7918          8        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      4.34G     0.1698     0.1217     0.7864          8        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      4.34G     0.1674     0.1186     0.7993          8        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 33.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      4.34G     0.1637     0.1124     0.7917          7        640: 100% ━━━━━━━━━━━━ 102/102 3.1it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      4.34G     0.1636     0.1073     0.7942          5        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         46         44      0.977          1      0.995      0.995
#
# 40 epochs completed in 0.423 hours.
# Optimizer stripped from /content/runs_compare_corrected/yolo11s/weights/last.pt, 19.2MB
# Optimizer stripped from /content/runs_compare_corrected/yolo11s/weights/best.pt, 19.2MB
#
# Validating /content/runs_compare_corrected/yolo11s/weights/best.pt...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
#                    all         46         44      0.956          1      0.995      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      10.2G      0.361     0.3227     0.8171         12        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44       0.96          1      0.995       0.98
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      10.2G     0.3359     0.2934     0.8081         13        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         46         44      0.998          1      0.995       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      10.2G     0.3488     0.2989     0.8154         13        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.996      0.955      0.955      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      10.2G     0.3191     0.2719     0.8098         18        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.994          1      0.995      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      10.2G     0.3074      0.256     0.8024         16        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.966
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      10.2G     0.2941     0.2493     0.8053         14        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.986          1      0.995       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      10.2G     0.2775     0.2331     0.7968         16        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      10.2G     0.2693     0.2212     0.7995         10        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      10.2G     0.2657     0.2195     0.8029         18        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      10.2G     0.2644     0.2193     0.7958          9        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.985          1      0.995      0.985
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      10.2G      0.254      0.212     0.7919          6        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      10.2G     0.2446     0.2006     0.7963         12        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                    all         46         44      0.999          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      10.2G      0.244     0.2132     0.7945         14        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      10.2G     0.2492      0.211     0.7938         16        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.977          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      10.2G     0.2311     0.1901     0.7888          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.998          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      10.2G     0.2333     0.1918     0.7948         18        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         46         44      0.999          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      10.2G     0.2261     0.1884     0.7894         18        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      10.2G     0.2265     0.1929      0.791         18        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      10.2G     0.2226     0.1804     0.7881         15        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      10.2G     0.2279       0.18     0.7932         16        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s
#                    all         46         44       0.99          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      10.2G     0.2246     0.1784      0.794         11        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      10.2G     0.2268     0.1792     0.7906          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      10.2G      0.219     0.1708     0.7891         11        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      10.2G     0.2095     0.1672     0.7937         22        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      10.2G     0.2035     0.1631     0.7905         16        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         46         44      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      10.2G     0.2022     0.1592     0.7873         17        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      10.2G     0.2032     0.1554     0.7984          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         46         44      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      10.2G     0.1987     0.1439     0.7916          7        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         46         44      0.997          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      10.2G     0.2028     0.1497     0.7949          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.994          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      10.2G     0.1926     0.1434     0.7944          6        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      10.2G     0.1854     0.1372     0.7911          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      10.2G     0.1812     0.1323     0.7917          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      10.2G     0.1761     0.1234     0.7874          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      10.2G     0.1746     0.1201     0.8001          8        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      10.2G       0.17     0.1156     0.7928          7        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      10.2G     0.1691     0.1116     0.7953          5        640: 100% ━━━━━━━━━━━━ 102/102 1.4it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         46         44      0.999          1      0.995      0.995
#
# 40 epochs completed in 1.084 hours.
# Optimizer stripped from /content/runs_compare_corrected/yolo11l/weights/last.pt, 51.2MB
# Optimizer stripped from /content/runs_compare_corrected/yolo11l/weights/best.pt, 51.2MB
#
# Validating /content/runs_compare_corrected/yolo11l/weights/best.pt...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11l summary (fused): 191 layers, 25,280,083 parameters, 0 gradients, 86.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         46         44      0.999          1      0.995      0.995
# Speed: 0.2ms preprocess, 8.9ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/runs_compare_corrected/yolo11l
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# #6.&nbsp;Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
import os

for model_path in models:
    run_name = model_path.replace(".pt", "")

    best_path = (
        f"{project_root}/"
        f"{run_name}/weights/best.pt"
    )

    if os.path.exists(best_path):
        print(f"{run_name}: weights found")
    else:
        print(
            f"{run_name}: weights not found at "
            f"{best_path}"
        )
# Out:
# yolo11n: weights found
# yolo11s: weights found
# yolo11m: weights found
# yolo11l: weights found

# %%
validation_output_root = (
    "/content/validation_outputs"
)

for model_path in models:
    run_name = model_path.replace(".pt", "")

    best_path = (
        f"{project_root}/"
        f"{run_name}/weights/best.pt"
    )

    if not os.path.exists(best_path):
        print(
            f"Skipping {run_name}: "
            "best.pt was not found."
        )
        continue

    print(
        f"\n===== Validating {run_name} =====\n"
    )

    # !yolo detect val \
        model={best_path} \
        data={data_path} \
        split=val \
        imgsz={imgsz} \
        project={validation_output_root} \
        name={run_name} \
        exist_ok=True
# Out:
# ===== Validating yolo11n =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2114.5±601.1 MB/s, size: 90.3 KB)
# val: Scanning /content/split_data/labels/val.cache... 46 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 7.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5it/s 1.2s
#                    all         46         44      0.978          1      0.995      0.995
# Speed: 4.6ms preprocess, 9.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/validation_outputs/yolo11n
# 💡 Learn more at https://docs.ultralytics.com/modes/val
#
# ===== Validating yolo11s =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1803.2±718.3 MB/s, size: 60.3 KB)
# val: Scanning /content/split_data/labels/val.cache... 46 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 7.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.5it/s 2.0s
#                    all         46         44      0.977          1      0.995      0.995
# Speed: 3.5ms preprocess, 19.9ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to /content/validation_outputs/yolo11s
# 💡 Learn more at https://docs.ultralytics.com/modes/val
#
# ===== Validating yolo11m =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,030,803 parameters, 0 gradients, 67.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2078.5±963.9 MB/s, size: 107.2 KB)
# val: Scanning /content/split_data/labels/val.cache... 46 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 6.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.8s
#                    all         46         44      0.997          1      0.995      0.995
# Speed: 4.8ms preprocess, 20.8ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /content/validation_outputs/yolo11m
# 💡 Learn more at https://docs.ultralytics.com/modes/val
#
# ===== Validating yolo11l =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11l summary (fused): 191 layers, 25,280,083 parameters, 0 gradients, 86.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2208.8±858.9 MB/s, size: 64.8 KB)
# val: Scanning /content/split_data/labels/val.cache... 46 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 10.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         46         44      0.999          1      0.995      0.995
# Speed: 3.3ms preprocess, 21.4ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /content/validation_outputs/yolo11l
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
test_source = (
    "/content/split_data/images/val"
)

prediction_output_root = (
    "/content/test_outputs"
)

for model_path in models:
    run_name = model_path.replace(".pt", "")

    best_path = (
        f"{project_root}/"
        f"{run_name}/weights/best.pt"
    )

    if not os.path.exists(best_path):
        print(
            f"Skipping {run_name}: "
            "best.pt was not found."
        )
        continue

    print(
        f"\n===== Predicting with "
        f"{run_name} =====\n"
    )

    # !yolo detect predict \
        model={best_path} \
        source={test_source} \
        imgsz={imgsz} \
        conf=0.25 \
        project={prediction_output_root} \
        name={run_name} \
        save=True \
        save_txt=True \
        save_conf=True \
        exist_ok=True
# Out:
# ===== Predicting with yolo11n =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.4 GFLOPs
#
# image 1/46 /content/split_data/images/val/045b2a18-042.jpg: 384x640 1 Interpreter, 8.9ms
# image 2/46 /content/split_data/images/val/090e8937-032.jpg: 384x640 1 Interpreter, 8.8ms
# image 3/46 /content/split_data/images/val/0b7aac8a-009.jpg: 384x640 1 Interpreter, 15.0ms
# image 4/46 /content/split_data/images/val/0c647ec7-frame_014.jpg: 384x640 1 Interpreter, 8.2ms
# image 5/46 /content/split_data/images/val/0e396ef3-frame_045.jpg: 384x640 1 Interpreter, 8.2ms
# image 6/46 /content/split_data/images/val/1df12416-frame_036.jpg: 384x640 1 Interpreter, 8.8ms
# image 7/46 /content/split_data/images/val/238797d8-frame_047.jpg: 384x640 1 Interpreter, 7.9ms
# image 8/46 /content/split_data/images/val/25ea1d61-026.jpg: 384x640 1 Interpreter, 8.0ms
# image 9/46 /content/split_data/images/val/2775ce09-063.jpg: 384x640 1 Interpreter, 8.1ms
# image 10/46 /content/split_data/images/val/2e9417b2-012.jpg: 384x640 1 Interpreter, 8.2ms
# image 11/46 /content/split_data/images/val/33152719-frame_048.jpg: 384x640 (no detections), 8.4ms
# image 12/46 /content/split_data/images/val/33d50ef7-frame_040.jpg: 384x640 1 Interpreter, 8.2ms
# image 13/46 /content/split_data/images/val/42eaeb79-frame_039.jpg: 384x640 1 Interpreter, 8.2ms
# image 14/46 /content/split_data/images/val/4c0160e3-frame_001.jpg: 384x640 1 Interpreter, 8.4ms
# image 15/46 /content/split_data/images/val/4c13860b-frame_004.jpg: 384x640 1 Interpreter, 8.0ms
# image 16/46 /content/split_data/images/val/4c30fc3a-frame_013.jpg: 384x640 1 Interpreter, 8.1ms
# image 17/46 /content/split_data/images/val/4d0704b2-015.jpg: 384x640 2 Interpreters, 8.1ms
# image 18/46 /content/split_data/images/val/5190ff96-032.jpg: 384x640 1 Interpreter, 8.2ms
# image 19/46 /content/split_data/images/val/53b243ab-048.jpg: 384x640 1 Interpreter, 8.2ms
# image 20/46 /content/split_data/images/val/5a2cfdec-frame_003.jpg: 384x640 1 Interpreter, 8.0ms
# image 21/46 /content/split_data/images/val/5c94a370-frame_032.jpg: 384x640 1 Interpreter, 8.2ms
# image 22/46 /content/split_data/images/val/6b45b427-frame_004.jpg: 384x640 1 Interpreter, 7.9ms
# image 23/46 /content/split_data/images/val/7f436e7a-086.jpg: 384x640 1 Interpreter, 7.9ms
# image 24/46 /content/split_data/images/val/7fa33347-frame_043.jpg: 384x640 1 Interpreter, 8.1ms
# image 25/46 /content/split_data/images/val/855f5c2b-frame_036.jpg: 384x640 1 Interpreter, 8.1ms
# image 26/46 /content/split_data/images/val/9533ef6e-frame_019.jpg: 384x640 1 Interpreter, 7.8ms
# image 27/46 /content/split_data/images/val/9dd54da6-frame_006.jpg: 384x640 1 Interpreter, 9.9ms
# image 28/46 /content/split_data/images/val/a4011a9d-frame_027.jpg: 384x640 1 Interpreter, 8.1ms
# image 29/46 /content/split_data/images/val/aae31cdc-frame_037.jpg: 384x640 1 Interpreter, 7.8ms
# image 30/46 /content/split_data/images/val/ab14d945-frame_001.jpg: 384x640 1 Interpreter, 7.8ms
# image 31/46 /content/split_data/images/val/b05c4364-frame_044.jpg: 384x640 1 Interpreter, 7.7ms
# image 32/46 /content/split_data/images/val/bcd92d00-frame_022.jpg: 384x640 1 Interpreter, 11.4ms
# image 33/46 /content/split_data/images/val/c0cc18a4-007.jpg: 384x640 1 Interpreter, 9.8ms
# image 34/46 /content/split_data/images/val/c7018efa-frame_005.jpg: 384x640 1 Interpreter, 8.0ms
# image 35/46 /content/split_data/images/val/ca4c99da-frame_031.jpg: 384x640 1 Interpreter, 9.2ms
# image 36/46 /content/split_data/images/val/cb1c432d-039.jpg: 384x640 1 Interpreter, 8.4ms
# image 37/46 /content/split_data/images/val/d106d9c4-050.jpg: 384x640 1 Interpreter, 10.5ms
# image 38/46 /content/split_data/images/val/d7fce3be-frame_018.jpg: 384x640 1 Interpreter, 8.5ms
# image 39/46 /content/split_data/images/val/d8ca02f6-frame_034.jpg: 384x640 1 Interpreter, 12.7ms
# image 40/46 /content/split_data/images/val/dea79901-008.jpg: 384x640 1 Interpreter, 8.2ms
# image 41/46 /content/split_data/images/val/e8bfc101-031.jpg: 384x640 1 Interpreter, 7.8ms
# image 42/46 /content/split_data/images/val/e9dbddec-frame_042.jpg: 384x640 1 Interpreter, 12.0ms
# image 43/46 /content/split_data/images/val/eb27a524-frame_043.jpg: 384x640 1 Interpreter, 8.4ms
# image 44/46 /content/split_data/images/val/f863ccdf-frame_017.jpg: 384x640 1 Interpreter, 8.5ms
# image 45/46 /content/split_data/images/val/f9d38103-frame_035.jpg: 384x640 1 Interpreter, 7.8ms
# image 46/46 /content/split_data/images/val/ff02832f-003.jpg: 384x640 (no detections), 8.2ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/test_outputs/yolo11n
# 44 labels saved to /content/test_outputs/yolo11n/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#
# ===== Predicting with yolo11s =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/46 /content/split_data/images/val/045b2a18-042.jpg: 384x640 1 Interpreter, 16.3ms
# image 2/46 /content/split_data/images/val/090e8937-032.jpg: 384x640 1 Interpreter, 15.6ms
# image 3/46 /content/split_data/images/val/0b7aac8a-009.jpg: 384x640 1 Interpreter, 14.0ms
# image 4/46 /content/split_data/images/val/0c647ec7-frame_014.jpg: 384x640 1 Interpreter, 15.2ms
# image 5/46 /content/split_data/images/val/0e396ef3-frame_045.jpg: 384x640 1 Interpreter, 14.6ms
# image 6/46 /content/split_data/images/val/1df12416-frame_036.jpg: 384x640 1 Interpreter, 13.5ms
# image 7/46 /content/split_data/images/val/238797d8-frame_047.jpg: 384x640 1 Interpreter, 10.8ms
# image 8/46 /content/split_data/images/val/25ea1d61-026.jpg: 384x640 1 Interpreter, 10.7ms
# image 9/46 /content/split_data/images/val/2775ce09-063.jpg: 384x640 1 Interpreter, 10.7ms
# image 10/46 /content/split_data/images/val/2e9417b2-012.jpg: 384x640 1 Interpreter, 10.7ms
# image 11/46 /content/split_data/images/val/33152719-frame_048.jpg: 384x640 (no detections), 10.7ms
# image 12/46 /content/split_data/images/val/33d50ef7-frame_040.jpg: 384x640 1 Interpreter, 10.8ms
# image 13/46 /content/split_data/images/val/42eaeb79-frame_039.jpg: 384x640 1 Interpreter, 10.8ms
# image 14/46 /content/split_data/images/val/4c0160e3-frame_001.jpg: 384x640 1 Interpreter, 10.7ms
# image 15/46 /content/split_data/images/val/4c13860b-frame_004.jpg: 384x640 1 Interpreter, 10.7ms
# image 16/46 /content/split_data/images/val/4c30fc3a-frame_013.jpg: 384x640 1 Interpreter, 10.7ms
# image 17/46 /content/split_data/images/val/4d0704b2-015.jpg: 384x640 2 Interpreters, 10.7ms
# image 18/46 /content/split_data/images/val/5190ff96-032.jpg: 384x640 1 Interpreter, 12.7ms
# image 19/46 /content/split_data/images/val/53b243ab-048.jpg: 384x640 1 Interpreter, 10.8ms
# image 20/46 /content/split_data/images/val/5a2cfdec-frame_003.jpg: 384x640 1 Interpreter, 10.8ms
# image 21/46 /content/split_data/images/val/5c94a370-frame_032.jpg: 384x640 1 Interpreter, 10.7ms
# image 22/46 /content/split_data/images/val/6b45b427-frame_004.jpg: 384x640 1 Interpreter, 10.8ms
# image 23/46 /content/split_data/images/val/7f436e7a-086.jpg: 384x640 1 Interpreter, 10.7ms
# image 24/46 /content/split_data/images/val/7fa33347-frame_043.jpg: 384x640 1 Interpreter, 10.7ms
# image 25/46 /content/split_data/images/val/855f5c2b-frame_036.jpg: 384x640 1 Interpreter, 10.7ms
# image 26/46 /content/split_data/images/val/9533ef6e-frame_019.jpg: 384x640 1 Interpreter, 10.8ms
# image 27/46 /content/split_data/images/val/9dd54da6-frame_006.jpg: 384x640 1 Interpreter, 10.7ms
# image 28/46 /content/split_data/images/val/a4011a9d-frame_027.jpg: 384x640 1 Interpreter, 10.7ms
# image 29/46 /content/split_data/images/val/aae31cdc-frame_037.jpg: 384x640 1 Interpreter, 10.7ms
# image 30/46 /content/split_data/images/val/ab14d945-frame_001.jpg: 384x640 1 Interpreter, 10.7ms
# image 31/46 /content/split_data/images/val/b05c4364-frame_044.jpg: 384x640 1 Interpreter, 10.7ms
# image 32/46 /content/split_data/images/val/bcd92d00-frame_022.jpg: 384x640 1 Interpreter, 10.7ms
# image 33/46 /content/split_data/images/val/c0cc18a4-007.jpg: 384x640 1 Interpreter, 10.7ms
# image 34/46 /content/split_data/images/val/c7018efa-frame_005.jpg: 384x640 1 Interpreter, 10.7ms
# image 35/46 /content/split_data/images/val/ca4c99da-frame_031.jpg: 384x640 1 Interpreter, 10.8ms
# image 36/46 /content/split_data/images/val/cb1c432d-039.jpg: 384x640 1 Interpreter, 10.7ms
# image 37/46 /content/split_data/images/val/d106d9c4-050.jpg: 384x640 1 Interpreter, 10.8ms
# image 38/46 /content/split_data/images/val/d7fce3be-frame_018.jpg: 384x640 1 Interpreter, 10.8ms
# image 39/46 /content/split_data/images/val/d8ca02f6-frame_034.jpg: 384x640 1 Interpreter, 10.8ms
# image 40/46 /content/split_data/images/val/dea79901-008.jpg: 384x640 1 Interpreter, 10.8ms
# image 41/46 /content/split_data/images/val/e8bfc101-031.jpg: 384x640 1 Interpreter, 10.8ms
# image 42/46 /content/split_data/images/val/e9dbddec-frame_042.jpg: 384x640 1 Interpreter, 10.8ms
# image 43/46 /content/split_data/images/val/eb27a524-frame_043.jpg: 384x640 1 Interpreter, 10.7ms
# image 44/46 /content/split_data/images/val/f863ccdf-frame_017.jpg: 384x640 1 Interpreter, 10.8ms
# image 45/46 /content/split_data/images/val/f9d38103-frame_035.jpg: 384x640 1 Interpreter, 10.8ms
# image 46/46 /content/split_data/images/val/ff02832f-003.jpg: 384x640 (no detections), 10.7ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/test_outputs/yolo11s
# 44 labels saved to /content/test_outputs/yolo11s/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#
# ===== Predicting with yolo11m =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,030,803 parameters, 0 gradients, 67.8 GFLOPs
#
# image 1/46 /content/split_data/images/val/045b2a18-042.jpg: 384x640 1 Interpreter, 23.9ms
# image 2/46 /content/split_data/images/val/090e8937-032.jpg: 384x640 1 Interpreter, 23.9ms
# image 3/46 /content/split_data/images/val/0b7aac8a-009.jpg: 384x640 1 Interpreter, 23.9ms
# image 4/46 /content/split_data/images/val/0c647ec7-frame_014.jpg: 384x640 1 Interpreter, 23.9ms
# image 5/46 /content/split_data/images/val/0e396ef3-frame_045.jpg: 384x640 1 Interpreter, 23.2ms
# image 6/46 /content/split_data/images/val/1df12416-frame_036.jpg: 384x640 1 Interpreter, 22.4ms
# image 7/46 /content/split_data/images/val/238797d8-frame_047.jpg: 384x640 1 Interpreter, 22.4ms
# image 8/46 /content/split_data/images/val/25ea1d61-026.jpg: 384x640 1 Interpreter, 22.4ms
# image 9/46 /content/split_data/images/val/2775ce09-063.jpg: 384x640 1 Interpreter, 22.4ms
# image 10/46 /content/split_data/images/val/2e9417b2-012.jpg: 384x640 1 Interpreter, 18.0ms
# image 11/46 /content/split_data/images/val/33152719-frame_048.jpg: 384x640 (no detections), 18.0ms
# image 12/46 /content/split_data/images/val/33d50ef7-frame_040.jpg: 384x640 1 Interpreter, 18.0ms
# image 13/46 /content/split_data/images/val/42eaeb79-frame_039.jpg: 384x640 1 Interpreter, 18.0ms
# image 14/46 /content/split_data/images/val/4c0160e3-frame_001.jpg: 384x640 1 Interpreter, 17.9ms
# image 15/46 /content/split_data/images/val/4c13860b-frame_004.jpg: 384x640 1 Interpreter, 18.0ms
# image 16/46 /content/split_data/images/val/4c30fc3a-frame_013.jpg: 384x640 1 Interpreter, 14.4ms
# image 17/46 /content/split_data/images/val/4d0704b2-015.jpg: 384x640 2 Interpreters, 14.4ms
# image 18/46 /content/split_data/images/val/5190ff96-032.jpg: 384x640 1 Interpreter, 14.4ms
# image 19/46 /content/split_data/images/val/53b243ab-048.jpg: 384x640 1 Interpreter, 13.8ms
# image 20/46 /content/split_data/images/val/5a2cfdec-frame_003.jpg: 384x640 1 Interpreter, 13.9ms
# image 21/46 /content/split_data/images/val/5c94a370-frame_032.jpg: 384x640 1 Interpreter, 13.9ms
# image 22/46 /content/split_data/images/val/6b45b427-frame_004.jpg: 384x640 1 Interpreter, 13.6ms
# image 23/46 /content/split_data/images/val/7f436e7a-086.jpg: 384x640 1 Interpreter, 13.6ms
# image 24/46 /content/split_data/images/val/7fa33347-frame_043.jpg: 384x640 1 Interpreter, 13.6ms
# image 25/46 /content/split_data/images/val/855f5c2b-frame_036.jpg: 384x640 1 Interpreter, 13.2ms
# image 26/46 /content/split_data/images/val/9533ef6e-frame_019.jpg: 384x640 1 Interpreter, 13.4ms
# image 27/46 /content/split_data/images/val/9dd54da6-frame_006.jpg: 384x640 1 Interpreter, 18.7ms
# image 28/46 /content/split_data/images/val/a4011a9d-frame_027.jpg: 384x640 1 Interpreter, 13.5ms
# image 29/46 /content/split_data/images/val/aae31cdc-frame_037.jpg: 384x640 1 Interpreter, 13.5ms
# image 30/46 /content/split_data/images/val/ab14d945-frame_001.jpg: 384x640 1 Interpreter, 13.5ms
# image 31/46 /content/split_data/images/val/b05c4364-frame_044.jpg: 384x640 1 Interpreter, 13.0ms
# image 32/46 /content/split_data/images/val/bcd92d00-frame_022.jpg: 384x640 1 Interpreter, 13.1ms
# image 33/46 /content/split_data/images/val/c0cc18a4-007.jpg: 384x640 1 Interpreter, 13.0ms
# image 34/46 /content/split_data/images/val/c7018efa-frame_005.jpg: 384x640 1 Interpreter, 13.3ms
# image 35/46 /content/split_data/images/val/ca4c99da-frame_031.jpg: 384x640 1 Interpreter, 13.3ms
# image 36/46 /content/split_data/images/val/cb1c432d-039.jpg: 384x640 1 Interpreter, 13.3ms
# image 37/46 /content/split_data/images/val/d106d9c4-050.jpg: 384x640 1 Interpreter, 13.0ms
# image 38/46 /content/split_data/images/val/d7fce3be-frame_018.jpg: 384x640 1 Interpreter, 13.0ms
# image 39/46 /content/split_data/images/val/d8ca02f6-frame_034.jpg: 384x640 1 Interpreter, 13.0ms
# image 40/46 /content/split_data/images/val/dea79901-008.jpg: 384x640 1 Interpreter, 13.0ms
# image 41/46 /content/split_data/images/val/e8bfc101-031.jpg: 384x640 1 Interpreter, 13.0ms
# image 42/46 /content/split_data/images/val/e9dbddec-frame_042.jpg: 384x640 1 Interpreter, 13.0ms
# image 43/46 /content/split_data/images/val/eb27a524-frame_043.jpg: 384x640 1 Interpreter, 13.0ms
# image 44/46 /content/split_data/images/val/f863ccdf-frame_017.jpg: 384x640 1 Interpreter, 13.0ms
# image 45/46 /content/split_data/images/val/f9d38103-frame_035.jpg: 384x640 1 Interpreter, 13.0ms
# image 46/46 /content/split_data/images/val/ff02832f-003.jpg: 384x640 (no detections), 13.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/test_outputs/yolo11m
# 44 labels saved to /content/test_outputs/yolo11m/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#
# ===== Predicting with yolo11l =====
#
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11l summary (fused): 191 layers, 25,280,083 parameters, 0 gradients, 86.8 GFLOPs
#
# image 1/46 /content/split_data/images/val/045b2a18-042.jpg: 384x640 1 Interpreter, 30.8ms
# image 2/46 /content/split_data/images/val/090e8937-032.jpg: 384x640 1 Interpreter, 30.9ms
# image 3/46 /content/split_data/images/val/0b7aac8a-009.jpg: 384x640 1 Interpreter, 30.7ms
# image 4/46 /content/split_data/images/val/0c647ec7-frame_014.jpg: 384x640 1 Interpreter, 30.7ms
# image 5/46 /content/split_data/images/val/0e396ef3-frame_045.jpg: 384x640 1 Interpreter, 30.7ms
# image 6/46 /content/split_data/images/val/1df12416-frame_036.jpg: 384x640 1 Interpreter, 21.6ms
# image 7/46 /content/split_data/images/val/238797d8-frame_047.jpg: 384x640 1 Interpreter, 21.6ms
# image 8/46 /content/split_data/images/val/25ea1d61-026.jpg: 384x640 1 Interpreter, 23.7ms
# image 9/46 /content/split_data/images/val/2775ce09-063.jpg: 384x640 1 Interpreter, 21.6ms
# image 10/46 /content/split_data/images/val/2e9417b2-012.jpg: 384x640 1 Interpreter, 20.3ms
# image 11/46 /content/split_data/images/val/33152719-frame_048.jpg: 384x640 (no detections), 19.5ms
# image 12/46 /content/split_data/images/val/33d50ef7-frame_040.jpg: 384x640 1 Interpreter, 19.5ms
# image 13/46 /content/split_data/images/val/42eaeb79-frame_039.jpg: 384x640 1 Interpreter, 18.9ms
# image 14/46 /content/split_data/images/val/4c0160e3-frame_001.jpg: 384x640 1 Interpreter, 18.7ms
# image 15/46 /content/split_data/images/val/4c13860b-frame_004.jpg: 384x640 1 Interpreter, 18.8ms
# image 16/46 /content/split_data/images/val/4c30fc3a-frame_013.jpg: 384x640 1 Interpreter, 15.3ms
# image 17/46 /content/split_data/images/val/4d0704b2-015.jpg: 384x640 1 Interpreter, 15.2ms
# image 18/46 /content/split_data/images/val/5190ff96-032.jpg: 384x640 1 Interpreter, 14.9ms
# image 19/46 /content/split_data/images/val/53b243ab-048.jpg: 384x640 1 Interpreter, 15.1ms
# image 20/46 /content/split_data/images/val/5a2cfdec-frame_003.jpg: 384x640 1 Interpreter, 14.9ms
# image 21/46 /content/split_data/images/val/5c94a370-frame_032.jpg: 384x640 1 Interpreter, 15.1ms
# image 22/46 /content/split_data/images/val/6b45b427-frame_004.jpg: 384x640 1 Interpreter, 14.9ms
# image 23/46 /content/split_data/images/val/7f436e7a-086.jpg: 384x640 1 Interpreter, 15.4ms
# image 24/46 /content/split_data/images/val/7fa33347-frame_043.jpg: 384x640 1 Interpreter, 15.7ms
# image 25/46 /content/split_data/images/val/855f5c2b-frame_036.jpg: 384x640 1 Interpreter, 15.2ms
# image 26/46 /content/split_data/images/val/9533ef6e-frame_019.jpg: 384x640 1 Interpreter, 14.8ms
# image 27/46 /content/split_data/images/val/9dd54da6-frame_006.jpg: 384x640 1 Interpreter, 14.6ms
# image 28/46 /content/split_data/images/val/a4011a9d-frame_027.jpg: 384x640 1 Interpreter, 15.1ms
# image 29/46 /content/split_data/images/val/aae31cdc-frame_037.jpg: 384x640 1 Interpreter, 14.7ms
# image 30/46 /content/split_data/images/val/ab14d945-frame_001.jpg: 384x640 1 Interpreter, 15.0ms
# image 31/46 /content/split_data/images/val/b05c4364-frame_044.jpg: 384x640 1 Interpreter, 14.3ms
# image 32/46 /content/split_data/images/val/bcd92d00-frame_022.jpg: 384x640 1 Interpreter, 14.7ms
# image 33/46 /content/split_data/images/val/c0cc18a4-007.jpg: 384x640 1 Interpreter, 14.9ms
# image 34/46 /content/split_data/images/val/c7018efa-frame_005.jpg: 384x640 1 Interpreter, 14.5ms
# image 35/46 /content/split_data/images/val/ca4c99da-frame_031.jpg: 384x640 1 Interpreter, 15.0ms
# image 36/46 /content/split_data/images/val/cb1c432d-039.jpg: 384x640 1 Interpreter, 15.0ms
# image 37/46 /content/split_data/images/val/d106d9c4-050.jpg: 384x640 1 Interpreter, 14.6ms
# image 38/46 /content/split_data/images/val/d7fce3be-frame_018.jpg: 384x640 1 Interpreter, 25.5ms
# image 39/46 /content/split_data/images/val/d8ca02f6-frame_034.jpg: 384x640 1 Interpreter, 14.7ms
# image 40/46 /content/split_data/images/val/dea79901-008.jpg: 384x640 1 Interpreter, 14.9ms
# image 41/46 /content/split_data/images/val/e8bfc101-031.jpg: 384x640 1 Interpreter, 15.5ms
# image 42/46 /content/split_data/images/val/e9dbddec-frame_042.jpg: 384x640 1 Interpreter, 15.5ms
# image 43/46 /content/split_data/images/val/eb27a524-frame_043.jpg: 384x640 1 Interpreter, 15.7ms
# image 44/46 /content/split_data/images/val/f863ccdf-frame_017.jpg: 384x640 1 Interpreter, 15.4ms
# image 45/46 /content/split_data/images/val/f9d38103-frame_035.jpg: 384x640 1 Interpreter, 15.0ms
# image 46/46 /content/split_data/images/val/ff02832f-003.jpg: 384x640 (no detections), 14.8ms
# Speed: 2.2ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/test_outputs/yolo11l
# 44 labels saved to /content/test_outputs/yolo11l/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
import os
from IPython.display import Image, display

for model_path in models:
    run_name = model_path.replace(".pt", "")

    prediction_folder = (
        f"{prediction_output_root}/{run_name}"
    )

    image_paths = glob.glob(
        f"{prediction_folder}/**/*.jpg",
        recursive=True
    )

    image_paths += glob.glob(
        f"{prediction_folder}/**/*.png",
        recursive=True
    )

    print(
        f"\n===== {run_name}: "
        f"{len(image_paths)} predictions =====\n"
    )

    for image_path in image_paths[:5]:
        display(
            Image(
                filename=image_path,
                height=400
            )
        )

        print(
            os.path.basename(image_path)
        )
# Out:
# ===== yolo11n: 46 predictions =====
# 7fa33347-frame_043.jpg
# dea79901-008.jpg
# ab14d945-frame_001.jpg
# f863ccdf-frame_017.jpg
# 0e396ef3-frame_045.jpg
#
# ===== yolo11s: 46 predictions =====
# 7fa33347-frame_043.jpg
# dea79901-008.jpg
# ab14d945-frame_001.jpg
# f863ccdf-frame_017.jpg
# 0e396ef3-frame_045.jpg
#
# ===== yolo11m: 46 predictions =====
# 7fa33347-frame_043.jpg
# dea79901-008.jpg
# ab14d945-frame_001.jpg
# f863ccdf-frame_017.jpg
# 0e396ef3-frame_045.jpg
#
# ===== yolo11l: 46 predictions =====
# 7fa33347-frame_043.jpg
# dea79901-008.jpg
# ab14d945-frame_001.jpg
# f863ccdf-frame_017.jpg
# 0e396ef3-frame_045.jpg

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
import os
import shutil

save_root = "/content/saved_models"
os.makedirs(save_root, exist_ok=True)

run_names = [
    model_path.replace(".pt", "")
    for model_path in models
]

for run_name in run_names:
    run_folder = os.path.join(
        project_root,
        run_name
    )

    zip_base = os.path.join(
        save_root,
        run_name
    )

    if not os.path.exists(run_folder):
        print(
            f"Skipping {run_name}: "
            f"{run_folder} was not found."
        )
        continue

    print(f"\n=== Zipping {run_name} ===")

    zip_path = shutil.make_archive(
        base_name=zip_base,
        format="zip",
        root_dir=project_root,
        base_dir=run_name
    )

    print(f"Saved: {zip_path}")
# Out:
# === Zipping yolo11n ===
# Saved: /content/saved_models/yolo11n.zip
#
# === Zipping yolo11s ===
# Saved: /content/saved_models/yolo11s.zip
#
# === Zipping yolo11m ===
# Saved: /content/saved_models/yolo11m.zip
#
# === Zipping yolo11l ===
# Saved: /content/saved_models/yolo11l.zip

# %%
import os
import pandas as pd

run_names = [
    model_path.replace(".pt", "")
    for model_path in models
]

summary_rows = []

for run_name in run_names:
    csv_path = os.path.join(
        project_root,
        run_name,
        "results.csv"
    )

    print(f"Reading: {csv_path}")

    if not os.path.exists(csv_path):
        print(
            f"Skipping {run_name}: "
            "results.csv was not found."
        )
        continue

    df = pd.read_csv(csv_path)

    # Remove leading or trailing spaces from column names.
    df.columns = df.columns.str.strip()

    metric_column = "metrics/mAP50-95(B)"

    if metric_column not in df.columns:
        print(
            f"Skipping {run_name}: "
            f"{metric_column} was not found."
        )

        print("Available columns:")
        print(df.columns.tolist())

        continue

    # Select the epoch with the highest mAP50-95.
    best_idx = df[metric_column].idxmax()
    best = df.loc[best_idx]

    summary_rows.append({
        "model": run_name,
        "best_epoch": int(best["epoch"]),
        "mAP50-95": float(
            best["metrics/mAP50-95(B)"]
        ),
        "mAP50": float(
            best["metrics/mAP50(B)"]
        ),
        "precision": float(
            best["metrics/precision(B)"]
        ),
        "recall": float(
            best["metrics/recall(B)"]
        ),
        "val_box_loss": float(
            best["val/box_loss"]
        ),
        "val_cls_loss": float(
            best["val/cls_loss"]
        ),
        "val_dfl_loss": float(
            best["val/dfl_loss"]
        )
    })

summary_df = pd.DataFrame(summary_rows)

if not summary_df.empty:
    summary_df = summary_df.sort_values(
        by="mAP50-95",
        ascending=False
    ).reset_index(drop=True)

    output_csv = (
        "/content/model_comparison_summary.csv"
    )

    summary_df.to_csv(
        output_csv,
        index=False
    )

    print(
        f"\nSaved comparison summary to "
        f"{output_csv}"
    )

    display(summary_df)
else:
    print(
        "\nNo model results were found. "
        "Check project_root and run names."
    )
# Out:
# Reading: /content/runs_compare_corrected/yolo11n/results.csv
# Reading: /content/runs_compare_corrected/yolo11s/results.csv
# Reading: /content/runs_compare_corrected/yolo11m/results.csv
# Reading: /content/runs_compare_corrected/yolo11l/results.csv
#
# Saved comparison summary to /content/model_comparison_summary.csv
#      model  best_epoch  mAP50-95  mAP50  precision  recall  val_box_loss  \
# 0  yolo11n           5     0.995  0.995    0.99715     1.0       0.21656
# 1  yolo11s          11     0.995  0.995    0.97620     1.0       0.20099
# 2  yolo11m          10     0.995  0.995    0.98371     1.0       0.20216
# 3  yolo11l          17     0.995  0.995    0.99816     1.0       0.21056
#
#    val_cls_loss  val_dfl_loss
# 0       0.28821       0.67183
# 1       0.17063       0.67008
# 2       0.19824       0.67660
# 3       0.17529       0.67320

# %% [markdown]
# 3.1. mAP50-95 bar chart

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 4))

bars = ax.bar(
    summary_df["model"],
    summary_df["mAP50-95"],
    color="steelblue"
)

ax.bar_label(
    bars,
    fmt="%.4f",
    label_type="center",
    color="white",
    fontsize=10,
    fontweight="bold"
)

ax.set_xlabel("Model")
ax.set_ylabel("mAP50-95 (B)")
ax.set_title("mAP50-95 Comparison Across Models")
ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.2. Precision & recall comparison

# %%
plt.figure(figsize=(6,4))
x = range(len(summary_df))

plt.plot(x, summary_df["precision"], marker="o", label="Precision")
plt.plot(x, summary_df["recall"], marker="o", label="Recall")

plt.xticks(x, summary_df["model"], rotation=45)
plt.ylabel("Score")
plt.title("Precision & Recall by Model")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3.3. “Regression-like” view: box & cls loss

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 4))

bars = ax.bar(
    summary_df["model"],
    summary_df["val_box_loss"],
    color="darkorange"
)

ax.bar_label(
    bars,
    fmt="%.4f",
    label_type="center",
    color="white",
    fontsize=10,
    fontweight="bold"
)

ax.set_xlabel("Model")
ax.set_ylabel("Validation Box Loss")
ax.set_title(
    "Validation Box Loss Across Models"
)
ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Look at confusion matrices & PR/F1 curves per model

# %%
from IPython.display import Image, display

for run_name in run_names:
    print(f"\n=== {run_name}: Confusion matrix (normalized) ===")
    cm_path = os.path.join(project_root, "detect", run_name, "confusion_matrix_normalized.png")
    display(Image(filename=cm_path))
# Out:
# === yolo11n: Confusion matrix (normalized) ===
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1593/2020619927.py in <cell line: 0>()
#       4     print(f"\n=== {run_name}: Confusion matrix (normalized) ===")
#       5     cm_path = os.path.join(project_root, "detect", run_name, "confusion_matrix_normalized.png")
# ----> 6     display(Image(filename=cm_path))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs_compare_corrected/detect/yolo11n/confusion_matrix_normalized.png'

# %%
for run_name in run_names:
    print(f"\n=== {run_name}: Precision-Recall curve ===")
    pr_path = os.path.join(project_root, "detect", run_name, "BoxPR_curve.png")
    display(Image(filename=pr_path))
# Out:
# === yolo11n: Precision-Recall curve ===
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1593/3550335965.py in <cell line: 0>()
#       2     print(f"\n=== {run_name}: Precision-Recall curve ===")
#       3     pr_path = os.path.join(project_root, "detect", run_name, "BoxPR_curve.png")
# ----> 4     display(Image(filename=pr_path))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs_compare_corrected/detect/yolo11n/BoxPR_curve.png'

# %%
for run_name in run_names:
    print(f"\n=== {run_name}: F1_curve ===")
    f1_path = os.path.join(project_root, "detect", run_name, "BoxF1_curve.png")
    display(Image(filename=f1_path))

# %% [markdown]
# Read hyperparameters from args.yaml

# %%
import yaml

for run_name in run_names:
    args_path = os.path.join(project_root, "detect", run_name, "args.yaml")
    with open(args_path, "r") as f:
        args = yaml.safe_load(f)
    print(f"\n=== Hyperparameters for {run_name} ===")
    print("epochs:", args.get("epochs"))
    print("imgsz:", args.get("imgsz"))
    print("optimizer:", args.get("optimizer"))
    print("lr0:", args.get("lr0"))
    print("lrf:", args.get("lrf"))
    print("momentum:", args.get("momentum"))
    # add anything else you want to report

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
